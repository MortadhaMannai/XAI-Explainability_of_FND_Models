# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Huggingface.utils import HuggingfaceDatasetManager, get_most_important_n_tokens, TransformersModelTypeEnum, ModelManager
# Out:
# This project is written and tested in Python 3.7.13

# %%
model_type = TransformersModelTypeEnum.CH_FAKE_TWEET_DETECT
model_manager = ModelManager(model_type)
# Out:
# Using device: cuda

# %% [markdown]
# ## Load the respective dataset

# %%
dataset_manager = HuggingfaceDatasetManager(model_type)
# Out:
# Loading instances from dir: /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/Huggingface/data/Chinhon_FakeTweetDetect/real_50k.csv
# Loaded 50000 instances from /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/Huggingface/data/Chinhon_FakeTweetDetect/real_50k.csv
# Loading instances from dir: /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/Huggingface/data/Chinhon_FakeTweetDetect/troll_50k.csv
# Loaded 50000 instances from /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/Huggingface/data/Chinhon_FakeTweetDetect/troll_50k.csv

# %%
true_samples = dataset_manager.fetch_true_samples()
true_sample_shap_values = model_manager.explain_texts(true_samples)
# Out:
# Getting the following indexes: [13817, 8564, 12928]
# [[{'label': 'LABEL_0', 'score': 0.9982927441596985}, {'label': 'LABEL_1', 'score': 0.0017072561895474792}], [{'label': 'LABEL_0', 'score': 0.9983571171760559}, {'label': 'LABEL_1', 'score': 0.0016428186791017652}], [{'label': 'LABEL_0', 'score': 0.9975722432136536}, {'label': 'LABEL_1', 'score': 0.0024278045166283846}]]
# Sample 0 is predicted True with score: 0.9982927441596985
# Sample 0 is predicted Fake with score: 0.0017072561895474792
# Sample 1 is predicted True with score: 0.9983571171760559
# Sample 1 is predicted Fake with score: 0.0016428186791017652
# Sample 2 is predicted True with score: 0.9975722432136536
# Sample 2 is predicted Fake with score: 0.0024278045166283846
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# ...
