# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Huggingface.utils import HuggingfaceDatasetManager, get_most_important_n_tokens, TransformersModelTypeEnum, ModelManager, barplot_token_shap_values
# Out:
# This project is written and tested in Python 3.7.13

# %%
model_type = TransformersModelTypeEnum.HB_ROBERTA_FAKE_NEWS
model_manager = ModelManager(model_type)
# Out:
# Using device: cuda

# %% [markdown]
# ## Load the respective dataset for the model

# %%
dataset_manager = HuggingfaceDatasetManager(model_type)
# Out:
# Loading instances from dir: /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/Huggingface/data/RobertaFakeNews/True.csv
# Loaded 21417 instances from /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/Huggingface/data/RobertaFakeNews/True.csv
# Loading instances from dir: /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/Huggingface/data/RobertaFakeNews/Fake.csv
# Loaded 23481 instances from /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/Huggingface/data/RobertaFakeNews/Fake.csv

# %%
labels, samples = dataset_manager.fetch_random_samples(sample_count=200)

# %%
shap_values_dict_list, explainer = model_manager.explain_texts(samples, visualize=False)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (933 > 512). Running this sequence through the model will result in indexing errors
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Partition explainer:  34%|███▎      | 67/200 [04:33<07:42,  3.48s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  40%|███▉      | 79/200 [05:34<10:21,  5.14s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  41%|████      | 82/200 [05:47<09:00,  4.58s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  42%|████▏     | 84/200 [05:59<09:53,  5.12s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  44%|████▍     | 89/200 [06:26<09:43,  5.26s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  48%|████▊     | 96/200 [07:00<07:34,  4.37s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  50%|█████     | 101/200 [07:24<08:04,  4.90s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  56%|█████▌    | 111/200 [08:04<05:31,  3.73s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  58%|█████▊    | 117/200 [08:24<04:23,  3.18s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  60%|█████▉    | 119/200 [08:33<04:44,  3.51s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  60%|██████    | 120/200 [08:38<05:30,  4.13s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  64%|██████▍   | 128/200 [09:07<04:06,  3.42s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  64%|██████▍   | 129/200 [09:13<04:55,  4.16s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  68%|██████▊   | 136/200 [09:46<04:39,  4.37s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  70%|███████   | 141/200 [10:12<04:22,  4.45s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  74%|███████▎  | 147/200 [10:39<03:56,  4.45s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  74%|███████▍  | 149/200 [10:50<04:14,  4.98s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  75%|███████▌  | 150/200 [10:56<04:23,  5.28s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  76%|███████▌  | 151/200 [11:02<04:20,  5.32s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  78%|███████▊  | 155/200 [11:18<03:16,  4.36s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  78%|███████▊  | 156/200 [11:23<03:24,  4.66s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  78%|███████▊  | 157/200 [11:29<03:30,  4.90s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  80%|███████▉  | 159/200 [11:37<02:57,  4.33s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  80%|████████  | 160/200 [11:43<03:10,  4.77s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  82%|████████▏ | 163/200 [11:58<02:59,  4.86s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  82%|████████▏ | 164/200 [12:03<03:01,  5.04s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  82%|████████▎ | 165/200 [12:10<03:13,  5.52s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  83%|████████▎ | 166/200 [12:16<03:10,  5.61s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  84%|████████▎ | 167/200 [12:22<03:07,  5.69s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  84%|████████▍ | 168/200 [12:27<03:02,  5.70s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  85%|████████▌ | 170/200 [12:35<02:18,  4.63s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  86%|████████▋ | 173/200 [12:48<01:48,  4.03s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  87%|████████▋ | 174/200 [12:53<01:56,  4.50s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  89%|████████▉ | 178/200 [13:08<01:23,  3.77s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  92%|█████████▏| 183/200 [13:27<00:59,  3.52s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  92%|█████████▏| 184/200 [13:33<01:06,  4.18s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  93%|█████████▎| 186/200 [13:40<00:54,  3.88s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  94%|█████████▎| 187/200 [13:48<01:04,  4.94s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  94%|█████████▍| 188/200 [13:54<01:02,  5.18s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  95%|█████████▌| 190/200 [14:02<00:45,  4.53s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  96%|█████████▌| 191/200 [14:08<00:44,  4.89s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  96%|█████████▋| 193/200 [14:14<00:26,  3.82s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  97%|█████████▋| 194/200 [14:20<00:26,  4.35s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  98%|█████████▊| 195/200 [14:25<00:23,  4.68s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer:  98%|█████████▊| 197/200 [14:36<00:15,  5.04s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 100%|██████████| 200/200 [14:46<00:00,  3.67s/it]
#   0%|          | 0/248 [00:00<?, ?it/s]
# Partition explainer: 201it [14:52,  4.51s/it]

# %%
tokens, shap_values = get_most_important_n_tokens(shap_values_dict_list[0], labels.iloc[0], n=10)
barplot_token_shap_values(tokens, shap_values)

# %%
import shap
shap.text_plot(shap_values_dict_list[0])
# Out:
# <div align='center'>
# <script>
#     document._hover_cnxedclrtzomunnjburp = '_tp_cnxedclrtzomunnjburp_output_0';
#     document._zoom_cnxedclrtzomunnjburp = undefined;
#     function _output_onclick_cnxedclrtzomunnjburp(i) {
#         var next_id = undefined;
#
#         if (document._zoom_cnxedclrtzomunnjburp !== undefined) {
#             document.getElementById(document._zoom_cnxedclrtzomunnjburp+ '_zoom').style.display = 'none';
#
#             if (document._zoom_cnxedclrtzomunnjburp === '_tp_cnxedclrtzomunnjburp_output_' + i) {
#                 document.getElementById(document._zoom_cnxedclrtzomunnjburp).style.display = 'block';
#                 document.getElementById(document._zoom_cnxedclrtzomunnjburp+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_cnxedclrtzomunnjburp).style.display = 'none';
#                 document.getElementById(document._zoom_cnxedclrtzomunnjburp+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_cnxedclrtzomunnjburp !== '_tp_cnxedclrtzomunnjburp_output_' + i) {
#             next_id = '_tp_cnxedclrtzomunnjburp_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_cnxedclrtzomunnjburp = next_id;
#     }
#     function _output_onmouseover_cnxedclrtzomunnjburp(i, el) {
#         if (document._zoom_cnxedclrtzomunnjburp !== undefined) { return; }
#         if (document._hover_cnxedclrtzomunnjburp !== undefined) {
#             document.getElementById(document._hover_cnxedclrtzomunnjburp + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_cnxedclrtzomunnjburp).style.display = 'none';
#         }
#         document.getElementById('_tp_cnxedclrtzomunnjburp_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_cnxedclrtzomunnjburp = '_tp_cnxedclrtzomunnjburp_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(230.2941176470614, 26.505882352939775, 102.59215686274348, 0.0); border-radius: 3px; padding: 0px" id="_tp_cnxedclrtzomunnjburp_output_0_name"
#     onclick="_output_onclick_cnxedclrtzomunnjburp(0)"
#     onmouseover="_output_onmouseover_cnxedclrtzomunnjburp(0, this);">Fake</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_cnxedclrtzomunnjburp_output_1_name"
#     onclick="_output_onclick_cnxedclrtzomunnjburp(1)"
#     onmouseover="_output_onmouseover_cnxedclrtzomunnjburp(1, this);">True</div><br><br><div id='_tp_cnxedclrtzomunnjburp_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="49.99999743834496%" y1="33" x2="49.99999743834496%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="49.99999743834496%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.33092608145898%" y1="33" x2="33.33092608145898%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.33092608145898%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="16.661854724573%" y1="33" x2="16.661854724573%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.661854724573%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="66.66906879523094%" y1="33" x2="66.66906879523094%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="66.66906879523094%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="83.33814015211692%" y1="33" x2="83.33814015211692%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="83.33814015211692%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="91.63071804188978%" y1="33" x2="91.63071804188978%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="91.63071804188978%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.999497</text><text x="91.63071804188978%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.999497</text><text x="91.63071804188978%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="8.330065276535434%" y1="33" x2="8.330065276535434%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="8.330065276535434%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">3.295e-05</text><text x="8.330065276535434%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">3.295e-05</text><text x="8.330065276535434%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">Fake</tspan>(inputs)</text><rect x="8.330065276535434%" width="0.0%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><rect transform="translate(-8,0)" x="8.330065276535434%" y="40" width="8" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792)"/><g transform="translate(-11.5,0)">  <svg x="8.330065276535434%" y="40" height="18" overflow="visible" width="30">    <path d="M 10 -9 l 6 18 L 10 25 L 0 25 L 0 -9" fill="#ffffff" style="stroke:rgb(255,255,255);stroke-width:2" />  </svg></g><rect x="8.330065276535434%" width="83.30065276535434%" y="40" height="18" style="fill:rgb(0.0, 138.56128015770724, 250.76166088685727); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="8.330065276535434%" x2="19.206537831219844%" y1="60" y2="60" id="_fb_ccskkknddanqnkdvditj_ind_6" style="stroke:rgb(0.0, 138.56128015770724, 250.76166088685727);stroke-width:2; opacity: 0"/><text x="13.768301553877638%" y="71" font-size="12px" fill="rgb(0.0, 138.56128015770724, 250.76166088685727)" id="_fs_ccskkknddanqnkdvditj_ind_6" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">-0.13</text><svg x="8.330065276535434%" y="40" height="20" width="10.87647255468441%">  <svg x="0" y= ...
