# %%
# %load_ext autoreload
# %autoreload 2
from util import plot_dataset_label_distribution_by_split
from GNNFakeNews.utils.helpers.gnn_dataset_manager import GNNDatasetManager
from GNNFakeNews.utils.helpers.hyperparameter_factory import HparamFactory
from GNNFakeNews.utils.enums import *

# %%
gos_dm = GNNDatasetManager(hparam_manager=HparamFactory(model_type=GNNModelTypeEnum.SAGE_GNN, dataset=GNNDatasetTypeEnum.GOSSIPCOP))
pol_dm = GNNDatasetManager(hparam_manager=HparamFactory(model_type=GNNModelTypeEnum.SAGE_GNN, dataset=GNNDatasetTypeEnum.POLITIFACT))
# Out:
# #################################
# -----> The hyperparameters are set!
# model_type = GNNModelTypeEnum.SAGE_GNN
# dataset = GNNDatasetTypeEnum.GOSSIPCOP
# batch_size = 128
# lr = 0.01
# weight_decay = 0.01
# n_hidden = 128
# epochs = 35
# feature = GNNFeatureTypeEnum.BERT
# concat = True
# transform = <GNNFakeNews.utils.data_loader.ToUndirected object at 0x7f5c63ad47d0>
# #################################
# Loading dataset 'gossipcop' from directory: /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/GNNFakeNews/data/local
# #################################
# -----> The hyperparameters are set!
# model_type = GNNModelTypeEnum.SAGE_GNN
# dataset = GNNDatasetTypeEnum.POLITIFACT
# batch_size = 128
# lr = 0.01
# weight_decay = 0.01
# n_hidden = 128
# epochs = 35
# feature = GNNFeatureTypeEnum.BERT
# concat = True
# transform = <GNNFakeNews.utils.data_loader.ToUndirected object at 0x7f5c63ac4750>
# #################################
# ...

# %%
plot_dataset_label_distribution_by_split(gos_dm.train_set, gos_dm.val_set, gos_dm.test_set, save_fig='GOS_DatasetDistrByLabelAndSplit')
# Out:
# len fake news 545
# len real news 547
# len fake news 267
# len real news 279
# len fake news 1920
# len real news 1906
# Total len: 5464

# %%
plot_dataset_label_distribution_by_split(pol_dm.train_set, pol_dm.val_set, pol_dm.test_set, save_fig='POL_DatasetDistrByLabelAndSplit')
# Out:
# len fake news 33
# len real news 29
# len fake news 16
# len real news 15
# len fake news 108
# len real news 113
# Total len: 314
