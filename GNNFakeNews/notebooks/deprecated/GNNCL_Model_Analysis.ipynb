# %% [markdown]
# ### helper file to handle GNNCL model implementation in https://github.com/safe-graph/GNN-FakeNews

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from util import run_model
from GNNFakeNews.utils.helpers.hyperparameter_factory import HparamFactory
from GNNFakeNews.utils.helpers.gnn_model_explainer import  GNNModelExplainer
from GNNFakeNews.utils.enums import GNNDatasetTypeEnum, GNNModelTypeEnum

# %%
model_type = GNNModelTypeEnum.GNNCL
pol_gnncl_model, pol_dataset_manager = run_model(model_type)
# Out:
# #################################
# -----> The hyperparameters are set!
# model_type = GNNModelTypeEnum.GNNCL
# dataset = GNNDatasetTypeEnum.POLITIFACT
# batch_size = 128
# lr = 0.001
# n_hidden = 128
# epochs = 60
# feature = GNNFeatureTypeEnum.PROFILE
# max_nodes = 500
# transform = ToDense(num_nodes=500)
# pre_transform = <GNNFakeNews.utils.data_loader.ToUndirected object at 0x7f0dd7783bd0>
# #################################
# Loading dataset 'politifact' from directory: /home/sersery/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/GNNFakeNews/data/local
# ...

# %%
sample_data_pol = pol_dataset_manager.get_random_train_samples(device=pol_gnncl_model.m_args.device)[0]
gnncl_model_politifact_explainer = GNNModelExplainer(pol_gnncl_model, sample_data_pol)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_834308/2073909537.py in <module>
#       1 sample_data_plt = pol_dataset_manager.get_random_train_samples(device=pol_gnncl_model.m_args.device)[0]
# ----> 2 upfd_model_politifact_explainer = GNNModelExplainer(pol_gnncl_model, sample_data_plt)
#
# ~/Desktop/TUM Informatik/SS22/Thesis/Code/Explainability_of_FND_Models/GNNFakeNews/utils/helpers.py in __init__(self, model, sample_data)
#     446         self.gnn_explainer = GNNExplainer(model, epochs=200).to(model.m_args.device)
#     447         self.node_feat_mask, self.edge_mask = self.gnn_explainer.explain_graph(x=sample_data.x,
# --> 448                                                                                edge_index=edge_index)
#     449
#     450     @staticmethod
#
# ...

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(20, 20))

# Full adjacency
ax.set_title('Full Adjacency mask')
ax.imshow(sample_data_pol.adj[:10, :10], cmap='gray')
plt.show()

# %%
sample_data_pol.adj.size()
# Out:
# torch.Size([500, 500])
